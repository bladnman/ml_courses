# %% [markdown]
# ## Course Information
# 🎥 **[COURSE VIDEOS](https://www.udemy.com/course/nlp-natural-language-processing-with-python/learn)**

# %% [markdown]
# ## Setup

# %%
# DRIVE
from google.colab import drive
drive.mount('/content/drive')

data_path = 'drive/MyDrive/Colab Notebooks/NLP Course/data'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Spacy

# %% [markdown]
# **If thing start to fail in the future run the following**

# %%
# !pip install https://github.com/explosion/spacy-models/releases/download/en_trf_xlnetbasecased_lg-2.2.0/en_trf_xlnetbasecased_lg-2.2.0.tar.gz

# %%
import spacy
# import spacy_transformers
# nlp = spacy.load('en_trf_xlnetbasecased_lg') 
nlp = spacy.load('en_core_web_sm')
print("All Spacy happy!")
# Out:
# All Spacy happy!

# %% [markdown]
# # NLP Basics
# - Spacey
# - NLTK

# %% [markdown]
# # Spacy Basics

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(u'Tesla is looking at buying U.S. startup for $6 million')

# %%
for token in doc:
  print(f"{token.text:12} {token.pos:5} {token.pos_:9} {token.dep_:9}")
# Out:
# Tesla           96 PROPN     nsubj
# is              87 AUX       aux
# looking        100 VERB      ROOT
# at              85 ADP       prep
# buying         100 VERB      pcomp
# U.S.            96 PROPN     compound
# startup         92 NOUN      dobj
# for             85 ADP       prep
# $               99 SYM       quantmod
# 6               93 NUM       compound
# million         93 NUM       pobj

# %%
nlp.pipeline
# Out:
# [('tagger', <spacy.pipeline.pipes.Tagger at 0x7f5314049090>),
#  ('parser', <spacy.pipeline.pipes.DependencyParser at 0x7f5314129c20>),
#  ('ner', <spacy.pipeline.pipes.EntityRecognizer at 0x7f53131f56e0>)]

# %%
nlp.pipe_names
# Out:
# ['tagger', 'parser', 'ner']

# %%
doc2 = nlp(u"Tesla isn't looking into startups anymore.")

# %%
for token in doc2:
  print(f"{token.text:12} {token.pos:5} {token.pos_:9} {token.dep_:9}")
# Out:
# Tesla           96 PROPN     nsubj
# is              87 AUX       aux
# n't             94 PART      neg
# looking        100 VERB      ROOT
# into            85 ADP       prep
# startups        92 NOUN      pobj
# anymore         86 ADV       advmod
# .               97 PUNCT     punct

# %%
# get individual tokens
doc2[0]
# Out:
# Tesla

# %%
doc2[0].pos_
# Out:
# 'PROPN'

# %% [markdown]
# # Spans
# Parts of a docuement

# %%
doc3 = nlp(u'Although commmonly attributed to John Lennon from his song "Beautiful Boy", \
the phrase "Life is what happens to us while we are making other plans" was written by \
cartoonist Allen Saunders and published in Reader\'s Digest in 1957, when Lennon was 17.')

# %%
life_quote = doc3[16:30]
print(life_quote)
# Out:
# "Life is what happens to us while we are making other plans"

# %%
type(life_quote)
# Out:
# spacy.tokens.span.Span

# %%
doc4 = nlp(u"This is the first sentence. This is another sentence. This is the last sentence.")

# %%
for sentence in doc4.sents:
  print(sentence)
# Out:
# This is the first sentence.
# This is another sentence.
# This is the last sentence.

# %%
token = doc4[6]

# %%
token.is_sent_start
# Out:
# True

# %% [markdown]
# # Tokenization

# %%
# Create a string that includes opening and closing quotation marks
mystring = '"We\'re moving to L.A.!"'
print(mystring)
# Out:
# "We're moving to L.A.!"

# %%
# Create a Doc object and explore tokens
doc = nlp(mystring)

for token in doc:
    print(token.text, end=' | ')
# Out:
# " | We | 're | moving | to | L.A. | ! | " |

# %%
doc2 = nlp(u"We're here to help! Send snail-mail, email support@oursite.com or visit us at http://www.oursite.com!")

for t in doc2:
    print(t)
# Out:
# We
# 're
# here
# to
# help
# !
# Send
# snail
# -
# mail
# ,
# email
# support@oursite.com
# or
# visit
# us
# at
# http://www.oursite.com
# !

# %%
doc3 = nlp(u'A 5km NYC cab ride costs $10.30')

for t in doc3:
    print(t)
# Out:
# A
# 5
# km
# NYC
# cab
# ride
# costs
# $
# 10.30

# %%
doc4 = nlp(u"Let's visit St. Louis in the U.S. next year.")

for t in doc4:
    print(t)
# Out:
# Let
# 's
# visit
# St.
# Louis
# in
# the
# U.S.
# next
# year
# .

# %% [markdown]
# <font color=green>Here the abbreviations for "Saint" and "United States" are both preserved.</font>

# %%
len(doc4.vocab)
# Out:
# 554

# %%
doc5 = nlp(u"It is better to give than receive.")

# %%
doc5[0]
# Out:
# It

# %%
doc5[2:5]
# Out:
# better to give

# %% [markdown]
# # Named Entities

# %%
doc8 = nlp(u'Apple to build a Hong Kong factory for $6 million')

for token in doc8:
    print(token.text, end=' | ')
# Out:
# Apple | to | build | a | Hong | Kong | factory | for | $ | 6 | million |

# %%
for entity in doc8.ents:
  print(entity)
  print(entity.label_)
  print(str(spacy.explain(entity.label_)))
  print()
# Out:
# Apple
# ORG
# Companies, agencies, institutions, etc.
#
# Hong Kong
# GPE
# Countries, cities, states
#
# $6 million
# MONEY
# Monetary values, including unit

# %% [markdown]
# # Noun Chunk

# %%
doc9 = nlp(u"Autonomous cars shift insurance liability toward manufacturers.")

for chunk in doc9.noun_chunks:
    print(chunk.text)
# Out:
# Autonomous cars
# insurance liability
# manufacturers

# %%
doc10 = nlp(u"Red cars do not carry higher insurance rates.")

for chunk in doc10.noun_chunks:
    print(chunk.text)
# Out:
# Red cars
# higher insurance rates

# %% [markdown]
# # Visualizing Tokenization

# %%
from spacy import displacy

# %%
doc = nlp(u"Apple is going to build a U.K. factory for $6 million.")

# %%
displacy.render(doc, style='dep', jupyter=True, options={'distance':75})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0f395978129342908af2abf0ce6dd1f9-0" class="displacy" width="950" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="125">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="125">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">going</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="275">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="275">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">build</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="425">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="425">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">U.K.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">factory</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="725">$</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="725">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">6</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="875">million.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="875">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0f395978129342908af2abf0ce6dd1f9-0-0" stroke-width="2px" d="M70,152.0 C70,77.0 190.0,77.0 190.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0f395978129342908af2abf0ce6dd1f9-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,154.0 L62,142.0 78,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0f395978129342908af2abf0ce6dd1f9-0-1" stroke-width="2px" d="M145,152.0 C145,114.5 185.0,114.5 185.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0f395978129342908af2abf0ce6dd1f9-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M145,154.0 L137,142.0 153,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0f395978129342908af2abf0ce6dd1f9-0-2" stroke-width="2px" d="M295,152.0 C295,114.5 335.0,114.5 335.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0f395978129342908af2abf0ce6dd1f9-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M295,154.0 L287,142.0 303,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0f395978129342908af2abf0ce6dd1f9-0-3" stroke-width="2px" d="M220,152.0 C220,77.0 340.0,77.0 340.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0f395978129342908af2abf0ce6dd1f9-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">xcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M340.0,154.0 L348.0,142.0 332.0,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0f395978129342908af2abf0ce6dd1f9-0-4" stroke-width="2px" d="M445,152.0 C445,77.0 565.0,77.0 565.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0f395978129342908af2abf0ce6dd1f9-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M445,154.0 L437,142.0 453,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0f395978129342908af2abf0ce6dd1f9-0-5" stroke-width="2px" d="M520,152.0 C520,114.5 560.0,114.5 560.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0f395978129342908af2abf0ce6dd1f9-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M520,154.0 L512,142.0 528,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0f395978129342908af2abf0ce6dd1f9-0-6" stroke-width="2px" d="M370,152.0 C370,39.5 570.0,39.5 570.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0f395978129342908af2abf0ce6dd1f9-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570.0,154.0 L578.0,142.0 562.0,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0f395978129342908af2abf0ce6dd1f9-0-7" stroke-width="2px" d="M370,152.0 C370,2.0 650.0,2.0 650.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0f395978129342908af2abf0ce6dd1f9-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M650.0,154.0 L658.0,142.0 642.0,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0f395978129342908af2a

# %%
doc = nlp(u'Over the last quarter Apple sold nearly 20 thousand iPods for profit of $6 million.')

# %%
displacy.render(doc, style='ent', jupyter=True, options={'distance':75})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last quarter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sold
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly 20 thousand
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     iPods
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  for profit of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $6 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# .</div></span>

# %%
# doc = nlp(u"This is a sentence.")
# displacy.serve(doc, style='dep')

# %% [markdown]
# # Stemming
#
# Stemming is reducing a word to its base:
# ```
# boating > boaters > boats = boat
# ```
# It is problematic enough in English which has many exceptions that Spacy does not include a Stemmer, rather opting for lemmetization.

# %%
import nltk

# %%
from nltk.stem.porter import PorterStemmer
from nltk.stem.snowball import SnowballStemmer

# %%
words = ['run','runner','ran','runs','easily','fairly', 'fairness', 'generous','generation','generate']

# %%
stemmer = PorterStemmer()
for word in words:
  print(f'{word:10} --->   {stemmer.stem(word):10}')
# Out:
# run        --->   run
# runner     --->   runner
# ran        --->   ran
# runs       --->   run
# easily     --->   easili
# fairly     --->   fairli
# fairness   --->   fair
# generous   --->   gener
# generation --->   gener
# generate   --->   gener

# %%
stemmer = SnowballStemmer(language='english')
for word in words:
  print(f'{word:10} --->   {stemmer.stem(word):10}')
# Out:
# run        --->   run
# runner     --->   runner
# ran        --->   ran
# runs       --->   run
# easily     --->   easili
# fairly     --->   fair
# fairness   --->   fair
# generous   --->   generous
# generation --->   generat
# generate   --->   generat

# %% [markdown]
# # Lemmatization
#
# Looking for a `lemma` of each word.

# %%
doc = nlp(u"I am a runner running in a race because I love to run since I ran today.")

# %%
def show_lemmas(text):
    for token in text:
        print(f'{token.text:{12}} {token.pos_:{6}} {token.lemma:<{22}} {token.lemma_}')

# %%
show_lemmas(doc)
# Out:
# I            PRON   561228191312463089     -PRON-
# am           AUX    10382539506755952630   be
# a            DET    11901859001352538922   a
# runner       NOUN   12640964157389618806   runner
# running      VERB   12767647472892411841   run
# in           ADP    3002984154512732771    in
# a            DET    11901859001352538922   a
# race         NOUN   8048469955494714898    race
# because      SCONJ  16950148841647037698   because
# I            PRON   561228191312463089     -PRON-
# love         VERB   3702023516439754181    love
# to           PART   3791531372978436496    to
# run          VERB   12767647472892411841   run
# since        SCONJ  10066841407251338481   since
# I            PRON   561228191312463089     -PRON-
# ran          VERB   12767647472892411841   run
# today        NOUN   11042482332948150395   today
# .            PUNCT  12646065887601541794   .

# %%
doc2 = nlp(u"I saw eighteen mice today!")

show_lemmas(doc2)
# Out:
# I            PRON   561228191312463089     -PRON-
# saw          VERB   11925638236994514241   see
# eighteen     NUM    9609336664675087640    eighteen
# mice         NOUN   1384165645700560590    mouse
# today        NOUN   11042482332948150395   today
# !            PUNCT  17494803046312582752   !

# %% [markdown]
# # Stop Words
#
# Get rid of the `305` words that add nothing but confusion.

# %%
print(nlp.Defaults.stop_words)
# Out:
# {"'s", 're', 'please', 'along', 'front', 'indeed', 'show', 'seems', 'each', 'towards', 'else', 'to', 'whenever', 'you', 'an', 'seemed', '’re', 'should', 'two', '‘s', 'among', 'but', 'themselves', 'where', 'therein', 'as', 'yourself', 'made', 'eight', 'than', 'nowhere', 'we', '‘ve', 'whereafter', 'perhaps', "n't", 'just', 'was', 'eleven', 'ours', 'whence', 'herein', 'its', 'ourselves', 'over', 'although', 'get', 'her', 'myself', 'with', 'various', 'never', 'have', 'amount', 'thus', 'yours', 'other', 'is', 'side', 'behind', 'formerly', 'yet', 'others', 'our', 'sometimes', 'part', 'in', 'meanwhile', 'below', 'they', 'fifty', 'mostly', 'ten', 'noone', 'either', 'thereby', 'because', 'until', "'ve", 'former', "'ll", 'becoming', 'hereafter', 'off', 'seeming', 'done', 'unless', 'anything', 'twenty', 'being', 'down', 'put', 'move', 'back', 'make', 'why', 'n’t', 'alone', 'beforehand', 'my', 'elsewhere', 'becomes', 'whole', '’s', 'it', 'own', 'due', 'whose', 'himself', 'next', 'that', 'between', 'full', "'m", 'upon', 'only', 'are', 'latterly', 'some', 'them', 'few', 'throughout', 'now', 'your', 'call', 'hereby', 'around', 'before', 'except', 'whereby', 'since', 'hereupon', 'latter', 'across', 'another', 'thence', 'afterwards', 'something', 'least', 'became', 'neither', 'does', 'did', 'nine', 'five', 'anyone', 'do', 'i', '‘re', 'also', 'used', 'amongst', 'during', 'at', 'somehow', 'beyond', 'everyone', 'four', 'so', 'thru', 'any', 'herself', 'three', 'give', 'his', 'everywhere', 'hence', 'n‘t', 'always', 'what', 'whither', 'hundred', 'above', 'go', 'seem', 'she', 'hers', 'if', 'whom', 'when', 'besides', 'whether', 'anyway', 'bottom', 'whereupon', 'be', 'who', 'all', 'can', 'onto', 'again', 'which', 'beside', 'ever', 'already', 'this', 'might', 'still', 'doing', 'has', '’ve', 'top', 'such', 'nor', 'fifteen', 'sixty', 'really', "'d", 'about', 'most', 'these', 'toward', 'first', 'enough', 'whatever', 'were', 'how', 'more', 'twelve', 'mine', 'too', 'once', 'every', 'sometime', 'take', '‘d', 'then', 'well', 'their', 'moreover', 'will', 'those', 'anywhere', 'may', 'against', 'using', '‘ll', 'however', 'on', 'though', 'forty', 'name', 'nevertheless', 'here', 'been', 'nobody', 'or', 'ca', 'whereas', 'regarding', 'third', 'thereupon', 'often', 'otherwise', '’m', 'under', 'would', '’d', 'without', 'see', 'empty', 'per', '‘m', 'one', 'wherever', 'itself', 'same', 'and', 'even', 'become', 'less', 'there', 'while', 'namely', 'quite', 'several', 'nothing', 'somewhere', 'therefore', 'anyhow', 'through', 'within', 'a', 'last', 'wherein', 'keep', '’ll', 'thereafter', 'after', 'he', 'by', 'serious', "'re", 'via', 'me', 'many', 'whoever', 'out', 'say', 'the', 'not', 'everything', 'six', 'must', 'none', 'us', 'no', 'into', 'am', 'of', 'up', 'both', 'very', 'together', 'could', 'rather', 'him', 'almost', 'further', 'cannot', 'much', 'someone', 'yourselves', 'from', 'had', 'for'}

# %%
nlp.vocab['is']

# %%
nlp.vocab['is'].is_stop
# Out:
# True

# %%
nlp.vocab['mystery'].is_stop
# Out:
# False

# %%
# Add new Stop Words if you like
nlp.Defaults.stop_words.add('btw')
nlp.vocab['btw'].is_stop = True
nlp.vocab['btw'].is_stop
# Out:
# True

# %%
# or remove any stop_words
nlp.Defaults.stop_words.remove('beyond')
nlp.vocab['beyond'].is_stop = False

# %% [markdown]
# # Vocabulary and Matching

# %% [markdown]
# ## Qualifiers and Tokens

# %% [markdown]
# This found both two-word patterns, with and without the hyphen!
#
# The following quantifiers can be passed to the `'OP'` key:
# <table><tr><th>OP</th><th>Description</th></tr>
#
# <tr ><td><span >\!</span></td><td>Negate the pattern, by requiring it to match exactly 0 times</td></tr>
# <tr ><td><span >?</span></td><td>Make the pattern optional, by allowing it to match 0 or 1 times</td></tr>
# <tr ><td><span >\+</span></td><td>Require the pattern to match 1 or more times</td></tr>
# <tr ><td><span >\*</span></td><td>Allow the pattern to match zero or more times</td></tr>
# </table>

# %% [markdown]
# ## Other token attributes
# Besides lemmas, there are a variety of token attributes we can use to determine matching rules:
# <table><tr><th>Attribute</th><th>Description</th></tr>
#
# <tr ><td><span >`ORTH`</span></td><td>The exact verbatim text of a token</td></tr>
# <tr ><td><span >`LOWER`</span></td><td>The lowercase form of the token text</td></tr>
# <tr ><td><span >`LENGTH`</span></td><td>The length of the token text</td></tr>
# <tr ><td><span >`IS_ALPHA`, `IS_ASCII`, `IS_DIGIT`</span></td><td>Token text consists of alphanumeric characters, ASCII characters, digits</td></tr>
# <tr ><td><span >`IS_LOWER`, `IS_UPPER`, `IS_TITLE`</span></td><td>Token text is in lowercase, uppercase, titlecase</td></tr>
# <tr ><td><span >`IS_PUNCT`, `IS_SPACE`, `IS_STOP`</span></td><td>Token is punctuation, whitespace, stop word</td></tr>
# <tr ><td><span >`LIKE_NUM`, `LIKE_URL`, `LIKE_EMAIL`</span></td><td>Token text resembles a number, URL, email</td></tr>
# <tr ><td><span >`POS`, `TAG`, `DEP`, `LEMMA`, `SHAPE`</span></td><td>The token's simple and extended part-of-speech tag, dependency label, lemma, shape</td></tr>
# <tr ><td><span >`ENT_TYPE`</span></td><td>The token's entity label</td></tr>
#
# </table>

# %%
from spacy.matcher import Matcher
matcher = Matcher(nlp.vocab)

# %%
# Looking for all of the following:
#   SolarPower
pattern1 = [{'LOWER':'solarpower'}]
#   Solar-Power
pattern2 = [{'LOWER':'solar'},{'IS_PUNCT':True},{'LOWER':'power'}]
#   Solar Power
pattern3 = [{'LOWER':'solar'},{'LOWER':'power'}]

# %%
matcher.add('SolarPower', None, pattern1, pattern2, pattern3)

# %%
doc = nlp(u'Solar--power FTW! The Solar Power industry continues to grow as demand \
for solarpower increases. Solar-power cars are gaining popularity.')

# %%
matcher(doc)
# Out:
# [(8656102463236116519, 0, 3),
#  (8656102463236116519, 6, 8),
#  (8656102463236116519, 15, 16),
#  (8656102463236116519, 18, 21)]

# %%
def print_matches(doc, matcher):
  found_matches = matcher(doc)
  for match_id, start, end in found_matches:
      string_id = nlp.vocab.strings[match_id]  # get string representation
      span = doc[start:end]                    # get the matched span
      print(f"{match_id:<24}{string_id:16}{start:7}{end:7} {span.text}")

# %%
print_matches(doc, matcher)
# Out:
# 8656102463236116519     SolarPower       0   3 Solar--power
# 8656102463236116519     SolarPower       6   8 Solar Power
# 8656102463236116519     SolarPower      15  16 solarpower
# 8656102463236116519     SolarPower      18  21 Solar-power

# %%
# remove them when not needed
matcher.remove('SolarPower')

# %%
pattern1 = [{'LOWER':'solarpower'}]
pattern2 = [{'LOWER':'solar'},{'IS_PUNCT':True, 'OP':'*'},{'LOWER':'power'}]

# %%
matcher.add('SolarPower', None, pattern1, pattern2)

# %%
print_matches(doc, matcher)
# Out:
# 8656102463236116519     SolarPower       0   3 Solar--power
# 8656102463236116519     SolarPower       6   8 Solar Power
# 8656102463236116519     SolarPower      15  16 solarpower
# 8656102463236116519     SolarPower      18  21 Solar-power

# %%
from spacy.matcher import PhraseMatcher
matcher = PhraseMatcher(nlp.vocab)

# %%
with open(f'{data_path}/reaganomics.txt', encoding="latin") as f:
  doc3 = nlp(f.read())

# %%
phrase_list = ['voodoo economics', 'supply-side economics', 'trickle-down economics', 'free-market economics']

# %%
phrase_patterns = [nlp(text) for text in phrase_list]

# %%
phrase_patterns
# Out:
# [voodoo economics,
#  supply-side economics,
#  trickle-down economics,
#  free-market economics]

# %%
matcher.add('EconMatcher', None, *phrase_patterns)

# %%
found_matches = matcher(doc3)

# %%
print_matches(doc3, matcher)
# Out:
# 3680293220734633682     EconMatcher          41     45 supply-side economics
# 3680293220734633682     EconMatcher          49     53 trickle-down economics
# 3680293220734633682     EconMatcher          54     56 voodoo economics
# 3680293220734633682     EconMatcher          61     65 free-market economics
# 3680293220734633682     EconMatcher         673    677 supply-side economics
# 3680293220734633682     EconMatcher        2986   2990 trickle-down economics

# %% [markdown]
# # Assessment
